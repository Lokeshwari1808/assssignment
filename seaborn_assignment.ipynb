# %% [markdown]
# """Q1: Name any five plots that we can plot using the Seaborn library. Also, state the uses of each plot."""
#
#
#
# """i.Histogram (seaborn.histplot):
#
# Use: Displays the distribution of a single numerical variable
#
# ii.Scatter Plot (seaborn.scatterplot):
#
# Use: Shows the relationship between two numerical variables.
#
# Scatter Plot (seaborn.scatterplot):
#
# Use: Shows the relationship between two numerical variables.
#
# Box Plot (seaborn.boxplot):
#
# Use: Displays the distribution of a numerical variable across different categories.
#
# Pairplot:
# Use: Display pairwise relationships in a dataset. Helpful for identifying correlations and distributions between multiple variables.
# jointplot:
# """

# %%
"""Q2: Load the "fmri" dataset using the load_dataset function of seaborn. Plot a line plot using x =
"timepoint" and y = "signal" for different events and regions."""
import seaborn as sns

# %%
fmri=sns.load_dataset('fmri')

# %%
fmri
# Out:
#      subject  timepoint event    region    signal
# 0        s13         18  stim  parietal -0.017552
# 1         s5         14  stim  parietal -0.080883
# 2        s12         18  stim  parietal -0.081033
# 3        s11         18  stim  parietal -0.046134
# 4        s10         18  stim  parietal -0.037970
# ...      ...        ...   ...       ...       ...
# 1059      s0          8   cue   frontal  0.018165
# 1060     s13          7   cue   frontal -0.029130
# 1061     s12          7   cue   frontal -0.004939
# 1062     s11          7   cue   frontal -0.025367
# 1063      s0          0   cue  parietal -0.006899
#
# [1064 rows x 5 columns]

# %%
sns.lineplot(x='timepoint',y='signal',data=fmri,hue='event',style='region')
# Out:
# <Axes: xlabel='timepoint', ylabel='signal'>

# %%
"""Que 3: Load the "titanic" dataset using the load_dataset function of seaborn. Plot two box plots using x =
'pclass', y = 'age' and y = 'fare'."""
import seaborn as sns

# %%
titanic=sns.load_dataset('titanic')

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(4,5))


sns.boxplot(x='pclass', y='age', data=titanic, ax=axes[0])
axes[0].set_title('Box Plot of Age by Pclass')
axes[0].set_xlabel('Pclass')
axes[0].set_ylabel('Age')


sns.boxplot(x='pclass', y='fare', data=titanic, ax=axes[1])
axes[1].set_title('Box Plot of Fare by Pclass')
axes[1].set_xlabel('Pclass')
axes[1].set_ylabel('Fare')
# Out:
# Text(0, 0.5, 'Fare')

# %%
"""Que 4: Use the "diamonds" dataset from seaborn to plot a histogram for the 'price' column. Use the hue
parameter for the 'cut' column of the diamonds dataset."""
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
diamonds_data = sns.load_dataset("diamonds")

plt.figure(figsize=(10, 6))
sns.histplot(data=diamonds_data, x='price', hue='cut', multiple='stack', bins=30, kde=True)


plt.title('Histogram of Diamond Prices by Cut')
plt.xlabel('Price')
plt.ylabel('Count')


plt.show()

# %%
"""Q5: Use the "iris" dataset from seaborn to plot a pair plot. Use the hue parameter for the "species" column
of the iris dataset."""
import seaborn as sns

# %%
iris=sns.load_dataset('iris')

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.pairplot(iris, hue='species')

# %%
"""Q6: Use the "flights" dataset from seaborn to plot a heatmap."""
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
flights=sns.load_dataset('flights')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load the "flights" dataset
flights_data = sns.load_dataset("flights")

# Pivot the data to create a matrix suitable for a heatmap
flights_matrix = flights_data.pivot_table(index='month', columns='year', values='passengers')

# Create a heatmap using Seaborn
plt.figure(figsize=(15, 10))
sns.heatmap(flights_matrix, annot=True)

# Set plot title and labels
plt.title('Passenger Count by Month and Year')
plt.xlabel('Year')
plt.ylabel('Month')

# Display the heatmap
plt.show()
# Out:
# C:\Users\LOKESHWARI\AppData\Local\Temp\ipykernel_3184\1097467116.py:8: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   flights_matrix = flights_data.pivot_table(index='month', columns='year', values='passengers')
